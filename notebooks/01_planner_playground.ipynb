# %% [markdown]
# # Meal Planner Playground
#
# Use this notebook to inspect the current profile, generate a sample day plan, and preview the grocery list logic before editing app code.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
SRC = ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from meal_planner.storage import Database
from meal_planner.services import GroceryService, PlannerService, ProfileService
from meal_planner.domain import start_of_week
from datetime import date

# %%
db = Database(ROOT / 'data' / 'meal_planner.db')
db.initialize()

with db.session() as session:
    profile = ProfileService(session).get_profile()
    overview = PlannerService(session).today_overview(date.today())
    grocery_list = GroceryService(session).get_weekly_list(start_of_week(date.today()))

profile, overview['nutrition'], len(grocery_list.items)

# %%
[(meal.meal_slot, meal.title, meal.notes) for meal in overview['day'].meals]

# %%
[(item.section, item.ingredient_name, item.quantity, item.unit) for item in grocery_list.items]
